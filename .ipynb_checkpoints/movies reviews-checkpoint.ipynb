# %%
import pandas as pd
from textblob import TextBlob 
import re, os

# %%
DATA_PATH = "D:\data\movies_reviews"
file = pd.read_csv(os.path.join(DATA_PATH, "test.tsv"), sep='\t')

# %%
def infrange(x, l, r):
    return x >=l and x < r

# %%
def sentiment(phrase):
    LEFT = -1.0
    RIGHT = 1.0
    analysis = TextBlob(phrase)
    score = analysis.sentiment.polarity
    print(f"Popuarity: {score}")
    score_nom = (score - LEFT)/(RIGHT - LEFT) * 5
    return int(score_nom)

# %%
for index, row in file.iterrows():
    print(f"Processing line {index}")
    print(sentiment(row["Phrase"]))
# Out:
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: -0.05
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.06666666666666667
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.06666666666666667
# 2
# Processing line {index}
# Popuarity: -0.06666666666666667
# 2
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.15833333333333335
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.15833333333333335
# 2
# Processing line {index}
# Popuarity: 0.15833333333333335
# 2
# Processing line {index}
# Popuarity: 0.21111111111111114
# 3
# Processing line {index}
# Popuarity: 0.21111111111111114
# 3
# Processing line {index}
# Popuarity: -0.16666666666666666
# 2
# Processing line {index}
# Popuarity: -0.16666666666666666
# 2
# Processing line {index}
# Popuarity: -0.16666666666666666
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.16666666666666666
# 2
# Processing line {index}
# Popuarity: -0.16666666666666666
# 2
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.3
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.16249999999999998
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.16249999999999998
# 2
# Processing line {index}
# Popuarity: -0.16249999999999998
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.16249999999999998
# 2
# Processing line {index}
# Popuarity: -0.21666666666666665
# 1
# Processing line {index}
# Popuarity: -0.35
# 1
# Processing line {index}
# Popuarity: -0.35
# 1
# Processing line {index}
# Popuarity: -0.35
# 1
# Processing line {index}
# Popuarity: -0.35
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.35
# 1
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0875
# 2
# Processing line {index}
# Popuarity: 0.0875
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.35
# 3
# Processing line {index}
# Popuarity: 0.35
# 3
# Processing line {index}
# Popuarity: 0.35
# 3
# Processing line {index}
# Popuarity: 0.35
# 3
# Processing line {index}
# Popuarity: 0.35
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.01666666666666668
# 2
# Processing line {index}
# Popuarity: 0.01666666666666668
# 2
# Processing line {index}
# Popuarity: 0.01666666666666668
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.01666666666666668
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.01666666666666668
# 2
# Processing line {index}
# Popuarity: 0.6
# 4
# Processing line {index}
# Popuarity: 0.6
# 4
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: -0.75
# 0
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.75
# 0
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.09416666666666668
# 2
# Processing line {index}
# Popuarity: -0.09416666666666668
# 2
# Processing line {index}
# Popuarity: -0.09416666666666668
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.09416666666666668
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.09416666666666668
# 2
# Processing line {index}
# Popuarity: -0.2916666666666667
# 1
# Processing line {index}
# Popuarity: -0.044791666666666674
# 2
# Processing line {index}
# Popuarity: -0.044791666666666674
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.044791666666666674
# 2
# Processing line {index}
# Popuarity: -0.044791666666666674
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.05972222222222223
# 2
# Processing line {index}
# Popuarity: -0.05972222222222223
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.05972222222222223
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.05972222222222223
# 2
# Processing line {index}
# Popuarity: -0.05972222222222223
# 2
# Processing line {index}
# Popuarity: 0.056249999999999994
# 2
# Processing line {index}
# Popuarity: 0.056249999999999994
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.056249999999999994
# 2
# Processing line {index}
# Popuarity: 0.056249999999999994
# 2
# Processing line {index}
# Popuarity: -0.1875
# 2
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.057142857142857134
# 2
# Processing line {index}
# Popuarity: -0.057142857142857134
# 2
# Processing line {index}
# Popuarity: -0.057142857142857134
# 2
# Processing line {index}
# Popuarity: -0.057142857142857134
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.057142857142857134
# 2
# Processing line {index}
# Popuarity: -0.057142857142857134
# 2
# Processing line {index}
# Popuarity: -0.057142857142857134
# 2
# Processing line {index}
# Popuarity: -0.21428571428571427
# 1
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.10666666666666666
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.13333333333333333
# 2
# Processing line {index}
# Popuarity: -0.13333333333333333
# 2
# Processing line {index}
# Popuarity: -0.13333333333333333
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.17777777777777778
# 2
# Processing line {index}
# Popuarity: -0.17777777777777778
# 2
# Processing line {index}
# Popuarity: -0.17777777777777778
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.17777777777777778
# 2
# Processing line {index}
# Popuarity: -0.17777777777777778
# 2
# Processing line {index}
# Popuarity: -0.17777777777777778
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.26666666666666666
# 1
# Processing line {index}
# Popuarity: -0.26666666666666666
# 1
# Processing line {index}
# Popuarity: -0.4
# 1
# Processing line {index}
# Popuarity: -0.4
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.13333333333333333
# 2
# Processing line {index}
# Popuarity: -0.33749999999999997
# 1
# Processing line {index}
# Popuarity: -0.33749999999999997
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: -0.6
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.20625
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.20625
# 1
# Processing line {index}
# Popuarity: -0.20625
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.20625
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.20625
# 1
# Processing line {index}
# Popuarity: -0.3125
# 1
# Processing line {index}
# Popuarity: -0.3125
# 1
# Processing line {index}
# Popuarity: -0.3125
# 1
# Processing line {index}
# Popuarity: -0.3125
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.016666666666666663
# 2
# Processing line {index}
# Popuarity: 0.016666666666666663
# 2
# Processing line {index}
# Popuarity: 0.016666666666666663
# 2
# Processing line {index}
# Popuarity: 0.016666666666666663
# 2
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: -0.1
# 2
# Processing line {index}
# Popuarity: -0.1
# 2
# Processing line {index}
# Popuarity: -0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.02500000000000001
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.02500000000000001
# 2
# Processing line {index}
# Popuarity: 0.02500000000000001
# 2
# Processing line {index}
# Popuarity: 0.10000000000000002
# 2
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.6
# 4
# Processing line {index}
# Popuarity: 0.6
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.6
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.07857142857142858
# 2
# Processing line {index}
# Popuarity: 0.09166666666666667
# 2
# Processing line {index}
# Popuarity: 0.1375
# 2
# Processing line {index}
# Popuarity: 0.1375
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.1375
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.1375
# 2
# Processing line {index}
# Popuarity: 0.125
# 2
# Processing line {index}
# Popuarity: 0.125
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.15
# 2
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.16
# 2
# Processing line {index}
# Popuarity: 0.16
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.16
# 2
# Processing line {index}
# Popuarity: 0.16
# 2
# Processing line {index}
# Popuarity: 0.19999999999999998
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.05
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.6
# 4
# Processing line {index}
# Popuarity: 0.6
# 4
# Processing line {index}
# Popuarity: 0.6
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.6999999999999998
# 0
# Processing line {index}
# Popuarity: -0.6999999999999998
# 0
# Processing line {index}
# Popuarity: -0.6999999999999998
# 0
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.6999999999999998
# 0
# Processing line {index}
# Popuarity: -0.6999999999999998
# 0
# Processing line {index}
# Popuarity: -0.6999999999999998
# 0
# Processing line {index}
# Popuarity: -0.6999999999999998
# 0
# Processing line {index}
# Popuarity: -0.6999999999999998
# 0
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.05189393939393939
# 2
# Processing line {index}
# Popuarity: 0.05189393939393939
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.1
# 2
# Processing line {index}
# Popuarity: 0.04227272727272727
# 2
# Processing line {index}
# Popuarity: -0.022159090909090913
# 2
# Processing line {index}
# Popuarity: -0.022159090909090913
# 2
# Processing line {index}
# Popuarity: 0.0037878787878787845
# 2
# Processing line {index}
# Popuarity: 0.0037878787878787845
# 2
# Processing line {index}
# Popuarity: 0.13636363636363635
# 2
# Processing line {index}
# Popuarity: 0.13636363636363635
# 2
# Processing line {index}
# Popuarity: 0.13636363636363635
# 2
# Processing line {index}
# Popuarity: 0.13636363636363635
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.0625
# 2
# Processing line {index}
# Popuarity: -0.125
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.1
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.3
# 3
# Processing line {index}
# Popuarity: 0.14285714285714288
# 2
# Processing line {index}
# Popuarity: 0.14285714285714288
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.03571428571428571
# 2
# Processing line {index}
# Popuarity: -0.03571428571428571
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.03571428571428571
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.07142857142857142
# 2
# Processing line {index}
# Popuarity: -0.07142857142857142
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.07142857142857142
# 2
# Processing line {index}
# Popuarity: -0.07142857142857142
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.07142857142857142
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.07142857142857142
# 2
# Processing line {index}
# Popuarity: -0.07142857142857142
# 2
# Processing line {index}
# Popuarity: -0.07142857142857142
# 2
# Processing line {index}
# Popuarity: -0.07142857142857142
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# ...
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.3
# 1
# Processing line {index}
# Popuarity: -0.3
# 1
# Processing line {index}
# Popuarity: -0.3
# 1
# Processing line {index}
# Popuarity: -0.3
# 1
# Processing line {index}
# Popuarity: -0.3
# 1
# Processing line {index}
# Popuarity: -0.3
# 1
# Processing line {index}
# Popuarity: -0.3
# 1
# Processing line {index}
# Popuarity: -0.44999999999999996
# 1
# Processing line {index}
# Popuarity: -0.44999999999999996
# 1
# Processing line {index}
# Popuarity: -0.2
# 2
# Processing line {index}
# Popuarity: -0.7
# 0
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.8
# 4
# Processing line {index}
# Popuarity: 0.5166666666666667
# 3
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.42500000000000004
# 3
# Processing line {index}
# Popuarity: 0.42500000000000004
# 3
# Processing line {index}
# Popuarity: 0.42500000000000004
# 3
# Processing line {index}
# Popuarity: 0.43333333333333335
# 3
# Processing line {index}
# Popuarity: 0.4166666666666667
# 3
# Processing line {index}
# Popuarity: 0.4166666666666667
# 3
# Processing line {index}
# Popuarity: 0.4166666666666667
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.4166666666666667
# 3
# Processing line {index}
# Popuarity: 0.4166666666666667
# 3
# Processing line {index}
# Popuarity: 0.4166666666666667
# 3
# Processing line {index}
# Popuarity: 0.4166666666666667
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.09999999999999999
# 2
# Processing line {index}
# Popuarity: 0.09999999999999999
# 2
# Processing line {index}
# Popuarity: 0.09999999999999999
# 2
# Processing line {index}
# Popuarity: 0.09999999999999999
# 2
# Processing line {index}
# Popuarity: 0.04999999999999999
# 2
# Processing line {index}
# Popuarity: 0.04999999999999999
# 2
# Processing line {index}
# Popuarity: 0.35
# 3
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: -0.25
# 1
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.04166666666666666
# 2
# Processing line {index}
# Popuarity: -0.04166666666666666
# 2
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: -0.3333333333333333
# 1
# Processing line {index}
# Popuarity: -0.3333333333333333
# 1
# Processing line {index}
# Popuarity: -0.3333333333333333
# 1
# Processing line {index}
# Popuarity: -0.3333333333333333
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.7
# 0
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.7
# 0
# Processing line {index}
# Popuarity: -0.7
# 0
# Processing line {index}
# Popuarity: -0.7
# 0
# Processing line {index}
# Popuarity: -0.7
# 0
# Processing line {index}
# Popuarity: -0.7
# 0
# Processing line {index}
# Popuarity: -0.7
# 0
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.21428571428571427
# 3
# Processing line {index}
# Popuarity: 0.21428571428571427
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.21666666666666667
# 1
# Processing line {index}
# Popuarity: -0.21666666666666667
# 1
# Processing line {index}
# Popuarity: -0.21666666666666667
# 1
# Processing line {index}
# Popuarity: -0.21666666666666667
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.21666666666666667
# 1
# Processing line {index}
# Popuarity: -0.21666666666666667
# 1
# Processing line {index}
# Popuarity: -0.21666666666666667
# 1
# Processing line {index}
# Popuarity: -0.1
# 2
# Processing line {index}
# Popuarity: -0.3333333333333333
# 1
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.3333333333333333
# 1
# Processing line {index}
# Popuarity: -0.3333333333333333
# 1
# Processing line {index}
# Popuarity: 0.44999999999999996
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.44999999999999996
# 3
# Processing line {index}
# Popuarity: 0.44999999999999996
# 3
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.7
# 4
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.2
# 3
# Processing line {index}
# Popuarity: 0.35
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.125
# 2
# Processing line {index}
# Popuarity: 0.125
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.5
# 1
# Processing line {index}
# Popuarity: 0.25
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.5
# 3
# Processing line {index}
# Popuarity: 0.16
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.4
# 3
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: 0.0
# 2
# Processing line {index}
# Popuarity: -0.012500000000000011
# 2
# Processing line {index}
# Popuarity: -0.012500000000000011
# 2
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.275
# 1
# Processing line {index}
# Popuarity: -0.30000000000000004
# 1
# Processing line {index}
# Popuarity: -0.30000000000000004
# 1
# Processing line {index}
# Popuarity: 0.25
# 3

# %%
print(file.iloc[0]["Phrase"])
sentiment(file.iloc[0]["Phrase"])
# Out:
# An intermittently pleasing but mostly routine effort .
# Popuarity: 0.5
# 3
